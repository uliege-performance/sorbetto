# %% [markdown]
# # Comparing No Skill Performances

# %% [markdown]
# In demos/no_skill_tiles, the notion of no skill performances is defined. In this notebook, we show that while changing prior and prediction rates, some canonical ranking scores remain the same. As expressed in the [*tile paper*](https://arxiv.org/abs/2412.04377), it is possible to obtain the analytical expresion for these points. That leads to a new tile that can be displayed here.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sorbetto.tile import Tile
from sorbetto.parameterization import ParameterizationDefault
from sorbetto.annotation import AnnotationGeometric

parameterization = ParameterizationDefault()

# %%
tile = Tile(
    parameterization=parameterization,
    name="Scores giving the same value to No-Skill Performances",
)
for prior_pos in np.linspace(0.05, 0.95, 19):
    curve = tile.parameterization.locateOrderingsPuttingNoSkillPerformancesOnAnEqualFootingForFixedClassPriors(
        prior_pos
    )
    plt_kwargs = dict()
    plt_kwargs["c"] = "palevioletred"
    annotation = AnnotationGeometric(curve, **plt_kwargs)
    tile.appendAnnotation(annotation)
fig, ax = tile.draw()

x0, x1, y0, y1 = tile.parameterization.getExtent()

mat = np.zeros((tile.resolution, tile.resolution))
for i, a_i in enumerate(np.linspace(x0 + 0.001, x1 - 0.001, tile.resolution)):
    for j, b_i in enumerate(np.linspace(y0 + 0.001, y1 - 0.001, tile.resolution)):
        mat[i, j] = ParameterizationDefault.getPriorNegForIsoValuedNoSkillPerformances(
            a_i, b_i
        )
im = ax.imshow(mat, extent=(0, 1, 0, 1), origin="lower", cmap="gray")
fig.colorbar(im, ax=ax, label="Constraint: prior of the negative class")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 12
#      10     plt_kwargs["c"] = "palevioletred"
#      11     annotation = AnnotationGeometric(curve, **plt_kwargs)
# ---> 12     tile.appendAnnotation(annotation)
#      13 fig, ax = tile.draw()
#      15 x0, x1, y0, y1 = tile.parameterization.getExtent()
#
# File ~/workspace/sorbetto/sorbetto/tile/_tile.py:233, in Tile.appendAnnotation(self, annotation)
#     230         logging.warning(message)
#     231         ok = False
# --> 233 constraint = self.getGlobalConstraintOnClassPriors()
#     234 if constraint is not None:
#     235     if not annotation.isCompatibleWithConstraintOnClassPriors(constraint):
#
# File ~/workspace/sorbetto/sorbetto/tile/_tile.py:436, in Tile.getGlobalConstraintOnClassPriors(self)
#     434 for annotation in self._annotations:
#     435     constraint = annotation.getConstraintOnClassPriors()
# --> 436     global_constraint = self._unionOfConstraints(global_constraint, constraint)
#     437 return global_constraint
#
# File ~/workspace/sorbetto/sorbetto/tile/_tile.py:401, in Tile._unionOfConstraints(self, constraint1, constraint2)
#     399     return constraint1
#     400 else:
# --> 401     raise NotImplementedError(
#     402         "Sorbetto does not support yet the union of different constraints"
#     403     )
#
# NotImplementedError: Sorbetto does not support yet the union of different constraints

# %%
tile = Tile(
    parameterization=parameterization,
    name="Scores giving the same value to No-Skill Performances",
)
for rate_pos in np.linspace(0.05, 0.95, 19):
    curve = tile.parameterization.locateOrderingsPuttingNoSkillPerformancesOnAnEqualFootingForFixedPredictionRates(
        rate_pos
    )
    plt_kwargs = dict()
    plt_kwargs["c"] = "cornflowerblue"
    annotation = AnnotationGeometric(curve, **plt_kwargs)
    tile.appendAnnotation(annotation)
fig, ax = tile.draw()

x0, x1, y0, y1 = tile.parameterization.getExtent()

mat = np.zeros((tile.resolution, tile.resolution))
for i, a_i in enumerate(np.linspace(x0 + 0.001, x1 - 0.001, tile.resolution)):
    for j, b_i in enumerate(np.linspace(y0 + 0.001, y1 - 0.001, tile.resolution)):
        mat[i, j] = (
            ParameterizationDefault.getRatePosPredictionsForIsoValuedNoSkillPerformances(
                a_i, b_i
            )
        )
ax.imshow(mat, extent=(0, 1, 0, 1), origin="lower", cmap="gray")
fig.colorbar(im, ax=ax, label="Constraint: rate of negative predictions")

plt.show()
