# %% [markdown]
# # Toy examples for entity tiles
#
# This jupyter notebook reproduces the three tiles of Figure 5 in :cite:t:`Pierard2024TheTile'.
#
# It provides toy examples showing entity tiles showing which of the 4 performances P− , P1 , P2 , and P+ is the best.
# The 3 examples differ in the class priors (either 0.2, 0.5, or 0.8 for the positive class).
# In all examples, P− (green) is the performance of classifiers predicting always the negative class, P1 (purple) is such that TNR(P1)=0.7 and TPR(P1)=0.7, P2 (yellow) is such that TNR(P2)=0.5 and TPR(P2)=0.8, and P+ (grey) is the performance of classifiers predicting always the positive class.

# %%
from sorbetto.core.entity import Entity
from sorbetto.performance.two_class_classification import TwoClassClassificationPerformance
from sorbetto.parameterization.parameterization_default import ParameterizationDefault
from sorbetto.tile.entity_tile import EntityTile
from sorbetto.flavor.entity_flavor import EntityFlavor

import matplotlib.pyplot as plt

cmap = plt.get_cmap('Dark2', 4)

#print(cmap(0))
#print(cmap(1))
#print(cmap(2))
#print(cmap(3))

# %%
# Print the colormap used for the entity tiles below
cmap

# %% [markdown]
# ## Example 1 for prior pos=0.2
#
# |       | P-   | P1   | P2   | P+   |
# | :--:  | :--: | :--: | :--: | :--: |
# | *PTN* | 0.80 | 0.56 | 0.40 | 0.00 |
# | *PFP* | 0.00 | 0.24 | 0.40 | 0.80 |
# | *PFN* | 0.20 | 0.06 | 0.04 | 0.00 |
# | *PTP* | 0.00 | 0.14 | 0.16 | 0.20 |

# %%
P_minus = Entity(TwoClassClassificationPerformance(0.8, 0.0, 0.2, 0.0), name = "P-", color = cmap(0))
P_one = Entity(TwoClassClassificationPerformance(0.56, 0.24, 0.06, 0.14), name = "P1", color = cmap(1))
P_two = Entity(TwoClassClassificationPerformance(0.4, 0.4, 0.04, 0.16), name = "P2", color = cmap(2))
P_plus = Entity(TwoClassClassificationPerformance(0.0, 0.8, 0.0, 0.2), name = "P+", color = cmap(3))

ex1_entity_flavor = EntityFlavor(rank = 1, entity_list = list([P_minus, P_one, P_two, P_plus]))
ex1_entity_tile = EntityTile(name = 'Entity Tile for prior pos=0.2', 
                             parameterization = ParameterizationDefault(),
                             flavor = ex1_entity_flavor,
                             resolution = 1001)

# ex1_entity_tile.draw()

tmp = ex1_entity_tile.compute_tile(ex1_entity_tile.sample_A, ex1_entity_tile.sample_B)
plt.imshow(tmp, origin="lower")
# Out:
# /Users/ahalin/GitHub/sorbetto/sorbetto/ranking/ranking_score.py:317: RuntimeWarning: invalid value encountered in divide
#   return satisfying / (satisfying + unsatisfying)

# %% [markdown]
# ## Example 2 for prior pos=0.5
#
# |       | P-   | P1   | P2   | P+   |
# | :--:  | :--: | :--: | :--: | :--: |
# | *PTN* | 0.50 | 0.35 | 0.25 | 0.00 |
# | *PFP* | 0.00 | 0.15 | 0.25 | 0.50 |
# | *PFN* | 0.50 | 0.15 | 0.10 | 0.00 |
# | *PTP* | 0.00 | 0.35 | 0.40 | 0.50 |

# %%
P_minus = Entity(TwoClassClassificationPerformance(0.5, 0.0, 0.5, 0.0), name = "P-", color = cmap(0))
P_one = Entity(TwoClassClassificationPerformance(0.35, 0.15, 0.15, 0.35), name = "P1", color = cmap(1))
P_two = Entity(TwoClassClassificationPerformance(0.25, 0.25, 0.10, 0.40), name = "P2", color = cmap(2))
P_plus = Entity(TwoClassClassificationPerformance(0.0, 0.5, 0.0, 0.5), name = "P+", color = cmap(3))

ex2_entity_flavor = EntityFlavor(rank = 1, entity_list = list([P_minus, P_one, P_two, P_plus]))
ex2_entity_tile = EntityTile(name = 'Entity Tile for prior pos=0.5', 
                             parameterization = ParameterizationDefault(),
                             flavor = ex2_entity_flavor,
                             resolution = 1001)

#ex2_entity_tile.draw()

tmp = ex2_entity_tile.compute_tile(ex2_entity_tile.sample_A, ex2_entity_tile.sample_B)
plt.imshow(tmp, origin="lower")

# %% [markdown]
# ## Example 3 for prior pos=0.8
#
# |       | P-   | P1   | P2   | P+   |
# | :--:  | :--: | :--: | :--: | :--: |
# | *PTN* | 0.20 | 0.14 | 0.10 | 0.00 |
# | *PFP* | 0.00 | 0.06 | 0.10 | 0.20 |
# | *PFN* | 0.80 | 0.24 | 0.16 | 0.00 |
# | *PTP* | 0.00 | 0.56 | 0.64 | 0.80 |

# %%
P_minus = Entity(TwoClassClassificationPerformance(0.2, 0.0, 0.8, 0.0), name = "P-", color = cmap(0))
P_one = Entity(TwoClassClassificationPerformance(0.14, 0.06, 0.24, 0.56), name = "P1", color = cmap(1))
P_two = Entity(TwoClassClassificationPerformance(0.1, 0.1, 0.16, 0.64), name = "P2", color = cmap(2))
P_plus = Entity(TwoClassClassificationPerformance(0.0, 0.2, 0.0, 0.8), name = "P+", color = cmap(3))

ex3_entity_flavor = EntityFlavor(rank = 1, entity_list = list([P_minus, P_one, P_two, P_plus]))
ex3_entity_tile = EntityTile(name = 'Entity Tile for prior pos=0.8', 
                             parameterization = ParameterizationDefault(),
                             flavor = ex3_entity_flavor,
                             resolution = 1001)

#ex3_entity_tile.draw()

tmp = ex3_entity_tile.compute_tile(ex3_entity_tile.sample_A, ex3_entity_tile.sample_B)
plt.imshow(tmp, origin="lower")
